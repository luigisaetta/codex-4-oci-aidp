# %% [markdown]
# # AI DP notebook smoke test
#
# This minimal example imports a Python standard-library module and prints the Python runtime version.

# %%
import platform

print(f"Python runtime: {platform.python_version()}")
